# %% [markdown]
# # Topic Modeling & Sentiment Analysis

# %% [markdown]
# ## Importing Dataset and Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.4-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.8.40)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (3.4.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.67.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.5.7)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.13.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.48.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.5.1+cu124)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.28.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (11.1.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.61.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2024.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (4.12.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.44.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.5)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.1.31)
# Downloading bertopic-0.16.4-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 12.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 65.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 46.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 8.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 69.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bertopic
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bertopic-0.16.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords

# BERTopic and UMAP
from bertopic import BERTopic
from umap import UMAP

# %%
business_df = pd.read_csv("/content/drive/MyDrive/Unstructured Data Analytics/F_filtered_business.csv")
review_df = pd.read_csv("/content/drive/MyDrive/Unstructured Data Analytics/F_filtered_review.csv")
tip_df = pd.read_csv("/content/drive/MyDrive/Unstructured Data Analytics/F_filtered_tip.csv")
user_df = pd.read_csv("/content/drive/MyDrive/Unstructured Data Analytics/F_filtered_user.csv")

# %% [markdown]
# ## Data Review

# %%
business_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9009 entries, 0 to 9008
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   9009 non-null   object
#  1   name          9009 non-null   object
#  2   address       8985 non-null   object
#  3   city          9009 non-null   object
#  4   state         9009 non-null   object
#  5   postal_code   9008 non-null   float64
#  6   latitude      9009 non-null   float64
#  7   longitude     9009 non-null   float64
#  8   stars         9009 non-null   float64
#  9   review_count  9009 non-null   int64
#  10  is_open       9009 non-null   int64
#  11  attributes    8951 non-null   object
#  12  categories    9009 non-null   object
#  13  hours         7982 non-null   object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 985.5+ KB

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007792 entries, 0 to 1007791
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   review_id    1007792 non-null  object
#  1   user_id      1007792 non-null  object
#  2   business_id  1007792 non-null  object
#  3   stars        1007792 non-null  int64
#  4   useful       1007792 non-null  int64
#  5   funny        1007792 non-null  int64
#  6   cool         1007792 non-null  int64
#  7   text         1007792 non-null  object
#  8   date         1007792 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 69.2+ MB

# %%
tip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131138 entries, 0 to 131137
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           131138 non-null  object
#  1   business_id       131138 non-null  object
#  2   text              131135 non-null  object
#  3   date              131138 non-null  object
#  4   compliment_count  131138 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 5.0+ MB

# %% [markdown]
# ## Data Preprocessing

# %%
# Process review_df (drop 3-star ratings and assign sentiment)
review_df.loc[review_df['stars'] >= 4, 'sentiment'] = 1
review_df.loc[review_df['stars'] == 3, 'sentiment'] = 0
review_df.loc[review_df['stars'] <= 2, 'sentiment'] = -1
# Merge review and tip files on user_id and business_id
merged_df = pd.merge(
    review_df,
    tip_df,
    on=['user_id', 'business_id'],
    how='inner'
)

# Merge with business data on business_id
merged_df = pd.merge(business_df, merged_df, on='business_id', how='inner')

merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63074 entries, 0 to 63073
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   business_id       63074 non-null  object
#  1   name              63074 non-null  object
#  2   address           63050 non-null  object
#  3   city              63074 non-null  object
#  4   state             63074 non-null  object
#  5   postal_code       63074 non-null  float64
#  6   latitude          63074 non-null  float64
#  7   longitude         63074 non-null  float64
#  8   stars_x           63074 non-null  float64
#  9   review_count      63074 non-null  int64
#  10  is_open           63074 non-null  int64
#  11  attributes        63044 non-null  object
#  12  categories        63074 non-null  object
#  13  hours             61188 non-null  object
#  14  review_id         63074 non-null  object
#  15  user_id           63074 non-null  object
#  16  stars_y           63074 non-null  int64
#  17  useful            63074 non-null  int64
#  18  funny             63074 non-null  int64
#  19  cool              63074 non-null  int64
#  20  text_x            63074 non-null  object
#  21  date_x            63074 non-null  object
#  22  sentiment         63074 non-null  int64
#  23  text_y            63073 non-null  object
#  24  date_y            63074 non-null  object
#  25  compliment_count  63074 non-null  int64
# dtypes: float64(4), int64(8), object(14)
# memory usage: 12.5+ MB

# %%
# 2. Remove stopwords from tip data
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def clean_text(text):
    # Basic text cleaning
    #   - Lowercasing
    #   - Removing non-alphabetic characters (optional)
    #   - Removing stopwords
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)  # remove punctuation/numbers, etc.
    words = [word for word in text.split() if word not in stop_words]
    return " ".join(words)

merged_df['cleaned_tip_text'] = merged_df['text_y'].astype(str).apply(clean_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Define the desired classes for each attribute.
desired_states = ['PA', 'FL']
desired_cuisines = ['Chinese', 'American', 'Italian']
desired_sentiments = [-1, 0, 1]

# Step 1: Create a cuisine column by extracting one of the desired cuisines from the 'categories' column.
def extract_cuisine(categories, cuisines_list=desired_cuisines):
    if isinstance(categories, str):
        for cuisine in cuisines_list:
            if cuisine.lower() in categories.lower():
                return cuisine
    return None  # return None if no desired cuisine is found

# Apply the extraction function to create a new column 'cuisine'.
merged_df['cuisine'] = merged_df['categories'].apply(extract_cuisine)

# Step 2: Filter the DataFrame to only include rows with desired sentiment, state, and cuisine.
filtered_df = merged_df[
    merged_df['state'].isin(desired_states) &
    merged_df['cuisine'].isin(desired_cuisines) &
    merged_df['sentiment'].isin(desired_sentiments)
]

# Step 3: Group by sentiment, state, and cuisine.
group_cols = ['sentiment', 'state', 'cuisine']
grouped = filtered_df.groupby(group_cols)

# Step 4: Determine the size of the smallest group.
min_count = grouped.size().min()
print("Minimum group count:", min_count)

# Step 5: Sample min_count rows from each group to balance the classes.
balanced_df = grouped.apply(lambda x: x.sample(min_count, random_state=42)).reset_index(drop=True)

print("Balanced DataFrame shape:", balanced_df.shape)
# Out:
# Minimum group count: 221
# Balanced DataFrame shape: (3978, 28)
# <ipython-input-28-5187cb61916d>:33: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %% [markdown]
# ## Topic Modeling for Tip's Data using UMap

# %%
# 3. Perform BERTopic modeling on the tip data using UMAP
umap_model = UMAP(
    n_neighbors=15,
    n_components=5,
    min_dist=0.0,
    random_state=42
)

topic_model = BERTopic(umap_model=umap_model)

# %%
# fit model on tip text of merged_df
merged_df = balanced_df.copy()
topics, probabilities = topic_model.fit_transform(merged_df['cleaned_tip_text'])

# %%
print(f"\nTotal number of topics: {len(topic_model.get_topic_info())}\n")

# Get top 10 topics and their information
top_10_topics = topic_model.get_topic_info().head(10)

# Print the top 10 topics and their information
top_10_topics
# Out:
# Total number of topics: 91
#    Topic  Count                              Name  \
# 0     -1   1374          -1_great_order_get_place
# 1      0     98      0_food_consistent_good_fresh
# 2      1     76             1_closed_open_pm_july
# 3      2     69             2_go_money_dont_waste
# 4      3     66    3_lunch_specials_special_fills
# 5      4     65  4_italian_authentic_instead_sell
# 6      5     65     5_service_terrible_poor_worst
# 7      6     56           6_sushi_rolls_roll_worm
# 8      7     55            7_soup_wonton_sour_hot
# 9      8     55   8_cheese_cheesesteak_steak_blue
#
#                                       Representation  \
# 0  [great, order, get, place, food, good, like, p...
# 1  [food, consistent, good, fresh, pretty, ago, g...
# 2  [closed, open, pm, july, permanently, opening,...
# 3  [go, money, dont, waste, back, refund, weeks, ...
# 4  [lunch, specials, special, fills, beverage, da...
# 5  [italian, authentic, instead, sell, dancing, f...
# 6  [service, terrible, poor, worst, bad, food, ho...
# 7  [sushi, rolls, roll, worm, california, fresh, ...
# 8  [soup, wonton, sour, hot, soups, tea, ton, tha...
# 9  [cheese, cheesesteak, steak, blue, steaks, chu...
#
#                                  Representative_Docs
# 0  [new favorite wine bar great food awesome atmo...
# 1  [food good, good food, place consistent food a...
# 2                           [closed, closed, closed]
# 3  [dont go, dont waste time money, go waste time...
# 4  [good lunch specials, lunch specials, lunch sp...
# 5  [italian beef sandwich, amazing italian lunch,...
# 6  [worst ever wont back horrible service food po...
# 7  [sushi rolls best ive area, sushi always amazi...
# 8  [wonton soup must, hot sour soup amazing, dont...
# 9            [get cheesesteak, great cheese, cheese]

# %%
# Further reduce topics to 30 clusters
topic_model = topic_model.reduce_topics(merged_df['cleaned_tip_text'], nr_topics=30)
topic_model.get_topic_info()
# Out:
#     Topic  Count                                  Name  \
# 0      -1   1374              -1_great_food_good_place
# 1       0   1056               0_food_good_lunch_great
# 2       1    268            1_pizza_italian_pasta_best
# 3       2    134                  2_go_dont_money_back
# 4       3    123             3_wine_beer_bar_selection
# 5       4     91           4_crab_shrimp_legs_calamari
# 6       5     85          5_service_slow_rude_horrible
# 7       6     76                 6_closed_open_pm_july
# 8       7     76       7_chinese_sichuan_food_szechuan
# 9       8     72               8_cash_tip_atm_gratuity
# 10      9     71  9_reservations_reservation_wait_make
# 11     10     65              10_place_miss_sucks_love
# 12     11     60      11_birthday_coupon_discount_yelp
# 13     12     43             12_parking_valet_lot_park
# 14     13     38            13_happy_hour_sundays_pmpm
# 15     14     38      14_patio_outside_seating_outdoor
# 16     15     37     15_menu_changes_tasting_something
# 17     16     34       16_delivery_order_deliver_gyros
# 18     17     32       17_brunch_dinner_mimosas_sunday
# 19     18     30          18_eat_dont_somewhere_hungry
# 20     19     29             19_ice_tea_bubble_dessert
# 21     20     28         20_wings_boneless_buffalo_get
# 22     21     21           21_ask_shes_waitress_waiter
# 23     22     19        22_pancakes_roti_pancake_canai
# 24     23     17            23_dim_sum_sumyum_everyday
# 25     24     16          24_kids_chairs_high_children
# 26     25     12          25_ribs_rib_smokey_singapore
# 27     26     11         26_gluten_free_options_crusts
# 28     27     11        27_salt_pepper_tofu_tofuenough
# 29     28     11          28_byob_fob_noyzee_townnever
#
#                                        Representation  \
# 0   [great, food, good, place, get, pizza, order, ...
# 1   [food, good, lunch, great, service, chicken, s...
# 2   [pizza, italian, pasta, best, philly, tampa, g...
# 3   [go, dont, money, back, waste, time, else, meh...
# 4   [wine, beer, bar, selection, beers, glasses, w...
# 5   [crab, shrimp, legs, calamari, lobster, fish, ...
# 6   [service, slow, rude, horrible, manager, custo...
# 7   [closed, open, pm, july, sign, opening, perman...
# 8   [chinese, sichuan, food, szechuan, authentic, ...
# 9   [cash, tip, atm, gratuity, charges, bring, car...
# 10  [reservations, reservation, wait, make, ahead,...
# 11  [place, miss, sucks, love, local, hit, slammin...
# 12  [birthday, coupon, discount, yelp, specials, c...
# 13  [parking, valet, lot, park, address, car, nort...
# 14  [happy, hour, sundays, pmpm, music, weekdays, ...
# 15  [patio, outside, seating, outdoor, view, sit, ...
# 16  [menu, changes, tasting, something, ask, cover...
# 17  [delivery, order, deliver, gyros, dont, anythi...
# 18  [brunch, dinner, mimosas, sunday, farewell, ex...
# 19  [eat, dont, somewhere, hungry, else, poisoning...
# 20  [ice, tea, bubble, dessert, smoothie, cream, h...
# 21  [wings, boneless, buffalo, get, flight, thursd...
# 22  [ask, shes, waitress, waiter, rose, shawn, rob...
# 23  [pancakes, roti, pancake, canai, theyre, scall...
# 24  [dim, sum, sumyum, everyday, sumserved, paste,...
# 25  [kids, chairs, high, children, child, act, mea...
# 26  [ribs, rib, smokey, singapore, sweet, tips, sp...
# 27  [gluten, free, options, crusts, gfree, glutenf...
# 28  [salt, pepper, tofu, tofuenough, salty, said, ...
# 29  [byob, fob, noyzee, townnever, fobs, byobs, le...
#
#                                   Representative_Docs
# 0   [love place great food service dont miss, good...
# 1   [good food, great food good service, good food...
# 2                [best pizza, pizza good, good pizza]
# 3                         [dont go, dont go, dont go]
# 4   [great beer selection great food, really authe...
# 5   [get crab soup, crab legs sushi, crab lobster ...
# 6       [great service, service great, great service]
# 7                            [closed, closed, closed]
# 8   [mediocre chinese food, worst chinese food eve...
# 9                                  [cash, cash, cash]
# 10  [make reservation, call ahead make reservation...
# 11            [place great, great place, great place]
# 12  [using free birthday bowl coupon, appears hono...
# 13  [valet parking validation, get early great par...
# 14               [happy hour, happy hour, happy hour]
# 15  [patio beautiful, beautiful outdoor patio, out...
# 16  [new spring menu, spring menu great, really go...
# 17               [delivery, delivery, order delivery]
# 18                           [brunch, brunch, brunch]
# 19                     [dont eat, dont eat, dont eat]
# 20             [bubble tea, thai ice tea, bubble tea]
# 21                [great wings, get wings, get wings]
# 22  [ask rose shes awesome love rose, amy awesome ...
# 23    [pancakes theyre good, best pancakes, pancakes]
# 24              [try dim sum, dim sum great, dim sum]
# 25  [parents going allow children play games video...
# 26  [first time definitely try sweet smokey ribs, ...
# 27  [vegetarian friendly gluten free options, glut...
# 28  [satisfying craving salt pepper tofu, get food...
# 29                           [great byob, byob, byob]

# %%
merged_df.head()
# Out:
#               business_id                             name  \
# 0  nYsNsyIppe_DTueBha1x9A                 Red Mesa Cantina
# 1  SvA2IQ9SyI1Dh7dtwNNs3A              Currents Restaurant
# 2  t6wBQeFXRFGqW8HhKJxBLQ  Fairway Pizza & Sports Page Pub
# 3  zT2OzXDWKK1abapHs2RUrQ              The Boardwalk Grill
# 4  lYQKK4KG7z4jMqMBVVfTNg              Taqueria Doña Maria
#
#                       address            city state  postal_code   latitude  \
# 0                128 3rd St S   St Petersburg    FL      33701.0  27.769715
# 1            200 E Tarpon Ave  Tarpon Springs    FL      34689.0  28.146050
# 2                 2901 Alt 19     Palm Harbor    FL      34683.0  28.094780
# 3  204 Johns Pass Boardwalk E   Madeira Beach    FL      33708.0  27.785742
# 4     865 Lithia Pinecrest Rd         Brandon    FL      33511.0  27.925585
#
#    longitude  stars_x  review_count  ...  funny cool  \
# 0 -82.636738      4.0          1427  ...      0    0
# 1 -82.754471      3.5           190  ...      0    0
# 2 -82.772960      3.0           101  ...      1    0
# 3 -82.781024      4.5          1060  ...      0    0
# 4 -82.270823      3.5           146  ...      1    0
#
#                                               text_x               date_x  \
# 0  Meh....Underwhelmed!    Blah.  Not much food. ...  2017-02-19 20:29:20
# 1  stopped going to Currents because food wasn't ...  2018-12-02 02:27:50
# 2  Despite the fact there was no rain, storm, etc...  2015-04-30 02:51:38
# 3  The food was good but the portion was to small...  2017-08-15 23:13:25
# 4  If you know me from yelp you will see I go aft...  2013-11-07 22:26:27
#
#   sentiment                                             text_y  \
# 0        -1                               Meh....Underwhelmed!
# 1        -1  Been going to Currents for years Tracy is the ...
# 2        -1                                  Not a good place.
# 3        -1     The food was good but the portion was to small
# 4        -1  If you know me from yelp you will see I go aft...
#
#                 date_y  compliment_count   cuisine  \
# 0  2017-02-19 20:26:36                 0  American
# 1  2021-06-12 20:05:42                 0  American
# 2  2015-04-30 02:56:30                 0  American
# 3  2017-08-07 19:48:05                 1  American
# 4  2013-10-26 17:15:59                 0  American
#
#                                     cleaned_tip_text
# 0                                    mehunderwhelmed
# 1                    going currents years tracy best
# 2                                         good place
# 3                            food good portion small
# 4  know yelp see go authentic cultural food decid...
#
# [5 rows x 28 columns]

# %%
# Retrieve document-level topic assignments and probabilities
doc_info = topic_model.get_document_info(merged_df['cleaned_tip_text'])

# Assign the topics and probabilities to the DataFrame
merged_df['reduced_topic'] = doc_info['Topic']
merged_df['topic_probability'] = doc_info['Probability']

# Get topic information from the model
topic_info = topic_model.get_topic_info()
# Create a mapping from topic ID to topic name (assuming the column 'Name' exists)
topic_mapping = dict(zip(topic_info.Topic, topic_info.Name))

# Map the numeric topics in your DataFrame to topic names
merged_df['topic_name'] = merged_df['reduced_topic'].map(topic_mapping)

# %%
merged_df.head(50)
# Out:
#                business_id                                     name  \
# 0   nYsNsyIppe_DTueBha1x9A                         Red Mesa Cantina
# 1   SvA2IQ9SyI1Dh7dtwNNs3A                      Currents Restaurant
# 2   t6wBQeFXRFGqW8HhKJxBLQ          Fairway Pizza & Sports Page Pub
# 3   zT2OzXDWKK1abapHs2RUrQ                      The Boardwalk Grill
# 4   lYQKK4KG7z4jMqMBVVfTNg                      Taqueria Doña Maria
# 5   AlH5V97JSAu7AL_xdibMIg                            Bahama Breeze
# 6   xGcpC8D4Sio-bN9KCr054g                 Zen Bistro Grill + Sushi
# 7   niJCOQ4-TxGklh2CVuCaTQ                           Steak ’n Shake
# 8   DhLIjn4oZHB0qzdlM5baFA                                     IHOP
# 9   1Vo4BLw75ntATAJHYsxO3g        Whiskey Joe's Bar & Grill - Tampa
# 10  1u2IlvwOMndfuRk9EVcieQ                              First Watch
# 11  _12864iQDcnAs317NlF0hQ                       Studio Movie Grill
# 12  vJTPB_SzizizBs8P-wV2cA                             Waffle House
# 13  3TdL8QTy4XOWo6BVQJIqQg                       Skip's Bar & Grill
# 14  ySn36gFeTJ0fR8CG-Q2DuA                             Smokey Bones
# 15  8RwPYPVmudJP_LrdPdJMyw             Golden Corral Buffet & Grill
# 16  b3tI8ODMieXSflFHLFA92A                           Cali - Brandon
# 17  DG6jtHuaEHj0Y4HgJl_NBA                       Fire Bar and Grill
# 18  _kgyGRCSf15RnynZN4LjJg                   Applebee's Grill + Bar
# 19  dgyKoIYEYrmRK_hktWBZdA                              The Getaway
# 20  ixPTo6Hum7nNZ7A4VPhTXg                 Brick House Tavern + Tap
# 21  1Vo4BLw75ntATAJHYsxO3g        Whiskey Joe's Bar & Grill - Tampa
# 22  tXfeVYKJq-bGPx1sjHOMHA                              Village Inn
# 23  KeM5P3tmiRbZQ-fldTPw9A                              Ferg's Live
# 24  ySn36gFeTJ0fR8CG-Q2DuA                             Smokey Bones
# 25  MOM0zyq3GMOy6W4xD2Rk5Q                    Marker 8 On the Water
# 26  rI9Ojso4-cd2blJdUgPBXA                           Steak ’n Shake
# 27  IwX-BnGpGPwVRLo8Ugrpgg                Popeyes Louisiana Kitchen
# 28  1Vo4BLw75ntATAJHYsxO3g        Whiskey Joe's Bar & Grill - Tampa
# 29  6ehbO-pVIO17bSYgNbugBA                             Los Jarrones
# 30  LPkl59vEZ7-jsEc3Txy3jA              McDivot's Wings and Raw Bar
# 31  lYQKK4KG7z4jMqMBVVfTNg                      Taqueria Doña Maria
# 32  7U7RauxQC439NNwLHodZ6A  Whiskey Joe's Bar & Grill - Port Richey
# 33  miuCbpDx1YphwfHwgaYoPA                 Palm Court Italian Grill
# 34  YLYLVY1HuQG1IvYjXyHzww                                     IHOP
# 35  k67rl4w58GIvmbTMnhTLaA                            Ford's Garage
# 36  jOSkKFMublb3b84KM77FcA                           Pollo Tropical
# 37  kH7U5_vVF-nomnoXAY_sIQ                              Smashburger
# 38  Kxgrqqy0RIEEabBCeizxgw                 Playerz Taphouse & Grill
# 39  A6SIUKApXnqlnAIRCpxzGw                         Tommy's Paradise
# 40  QHWYlmVbLC3K6eglWoHVvA                                     Datz
# 41  r9K46WZQ_hCi8vyyHV_tFw                         The Brass Monkey
# 42  cmvseNCdevDdxbxlz3KkWw                    Shrimpys Blues Bistro
# 43  K-FBBLhWuwhRcwuhm19Upg                       Crowley's Downtown
# 44  nuZm_f6EzuJTu3iT_b6DGw                   Applebee's Grill + Bar
# 45  p_qSQwShIgQnNxGcajI4-w                          Oxford Exchange
# 46  ptEhxv7nZLLM4eDngNMHJA                                  Chili's
# 47  ExcFu7R8ATHczORJ4opEUA                              Metro Diner
# 37  27.916758 -82.731400      3.0            77  ...  2017-01-29 20:28:24
# 38  27.770339 -82.635279      2.5            19  ...  2016-09-07 13:59:55
# 39  28.145751 -82.578599      3.0            22  ...  2013-07-14 18:25:24
# 40  27.921942 -82.493253      4.0          3260  ...  2015-05-04 00:06:56
# 41  27.687805 -82.737664      3.5           383  ...  2014-09-25 13:12:22
# 42  27.755835 -82.759691      4.5          1008  ...  2019-04-04 22:36:11
# 43  27.771365 -82.636711      4.0           194  ...  2014-05-18 22:15:37
# 44  27.871699 -82.761946      2.0            53  ...  2017-01-18 05:45:52
# 45  27.945114 -82.464621      4.5          1868  ...  2019-08-16 01:08:18
# 46  27.981144 -82.122270      2.5            40  ...  2013-09-27 01:45:36
# 47  27.819993 -82.639058      4.0           552  ...  2016-08-02 20:09:41
# 48  27.937277 -82.297141      3.0            99  ...  2018-07-29 22:26:59
# 49  28.126583 -82.370674      3.5           229  ...  2016-02-06 22:17:46
#
#    sentiment                                             text_y  \
# 0         -1                               Meh....Underwhelmed!
# 1         -1  Been going to Currents for years Tracy is the ...
# 2         -1                                  Not a good place.
# 3         -1     The food was good but the portion was to small
# 4         -1  If you know me from yelp you will see I go aft...
# 5         -1                      Great patio overlooking water
# 6         -1  Bad experience: Walked out paying about $6 in ...
# 7         -1  No more berry berry cobbler ala mode, no more me!
# 8         -1                                          Free WiFi
# 9         -1  Even though there's an empty parking lot there...
# 10        -1            Use "No Wait" App to get a table faster
# 11        -1  This place has horrible service. And the leade...
# 12        -1  I love waffle house but this was the worst one...
# 13        -1                           Beer wine and cash only.
# 14        -1                                  Smokehouse Wings!
# 15        -1            Only took 1 hr for diarrhea to kick in!
# 16        -1  Closed for flu season\n\nNo dining in\n\nNo ta...
# 17        -1         Good sliders specials on Football Sundays!
# 18        -1                                    Don't eat here!
# 19        -1  Waited on by one of the rudest servers I have ...
# 20        -1        Happy hour M-F 3-7PM!\n\nPretty sweet deals
# 21        -1  If you like your bank account do go to this pl...
# 22        -1  Invest in Depends Adult diapers, your going to...
# 23        -1  Do not start a tab they will add drinks to it ...
# 24        -1                                    open till 2a.m.
# 25        -1                                     Ask for Sharon
# 26        -1  If you want hair in your food this is the plac...
# 27        -1  After reading other reviews, I can see a bad p...
# 28        -1  Great view Salad was super spicy! Didn't see t...
# 29        -1  Sign says los jarrones menu says la gran colombia
# 30        -1  My tip:  Perhaps you might want to bring the H...
# 31        -1           Bad service. The food needs more flavor.
# 32        -1  Nice view, but waitress had a crappy personali...
# 33        -1  Save you're money. You're better off eating ou...
# 34        -1               Service sucks on a Sunday afternoon.
# 35        -1           Staff is great .. Wendy's food is better
# 36        -1                   NO SAUCE and the employees suck!
# 37        -1  Took 25 minutes to get my ONE burger. When the...
# 38        -1  Note: the address is 169 1st Ave NORTH not sou...
# 39        -1                              Laid back local place
# 40        -1            So we waited and waited and waited.....
# 41        -1  Bad grouper sandwich, server didn't seem conce...
# 42        -1                                  Eclectic and nice
# 43        -1  Its a great, high energy hang out with good food.
# 44        -1  This location isn't my favorite, the service i...
# 17             good sliders specials football sundays             11
# 18                                           dont eat             18
# 19          waited one rudest servers observed return              5
# 20                happy hour mf pm pretty sweet deals             13
# 21                  like bank account go place priced             11
# 22       invest depends adult diapers going need meal             -1
# 23                 start tab add drinks claim ordered             -1
# 24                                          open till              6
# 25                                         ask sharon             21
# 26                               want hair food place             -1
# 27  reading reviews see bad pattern slow service f...              0
# 28  great view salad super spicy didnt see one coming              0
# 29  sign says los jarrones menu says la gran colombia             -1
# 30  tip perhaps might want bring heinz mcdivots of...              0
# 31                      bad service food needs flavor             -1
# 32  nice view waitress crappy personality cannot g...             21
# 33  save youre money youre better eating vending m...             -1
# 34                     service sucks sunday afternoon              5
# 35                     staff great wendys food better              0
# 36                               sauce employees suck             -1
# 37  took minutes get one burger girl brought didnt...              0
# 38             note address st ave north south listed             12
# 39                              laid back local place             10
# 40                               waited waited waited              9
# 41  bad grouper sandwich server didnt seem concern...              0
# 42                                      eclectic nice             -1
# 43                   great high energy hang good food              0
# 44        location isnt favorite service slow food eh              0
# 45                   basically upscale cracker barrel             -1
# 46  fajita trio ridiculously small give three tort...              0
# 47                                            get pay              8
# 48             worst service ever new manager helpful              5
# 49                                good food last time              0
#
#     topic_probability                            topic_name
# 0            0.000000              -1_great_food_good_place
# 1            1.000000                  2_go_dont_money_back
# 2            1.000000              10_place_miss_sucks_love
# 3            1.000000               0_food_good_lunch_great
# 4            0.000000              -1_great_food_good_place
# 5            0.985872      14_patio_outside_seating_outdoor
# 6            0.268026               8_cash_tip_atm_gratuity
# 7            0.000000              -1_great_food_good_place
# 8            0.000000              -1_great_food_good_place
# 9            0.568201             12_parking_valet_lot_park
# 10           0.700470  9_reservations_reservation_wait_make
# 11           0.229992          5_service_slow_rude_horrible
# 12           0.000000              -1_great_food_good_place
# 13           0.704423             3_wine_beer_bar_selection
# 14           1.000000         20_wings_boneless_buffalo_get
# 15           0.000000              -1_great_food_good_place
# 16           1.000000               0_food_good_lunch_great
# 17           0.825031      11_birthday_coupon_discount_yelp
# 18           0.995930          18_eat_dont_somewhere_hungry
# 19           1.000000          5_service_slow_rude_horrible
# 20           0.318338            13_happy_hour_sundays_pmpm
# 21           0.687678      11_birthday_coupon_discount_yelp
# 22           0.000000              -1_great_food_good_place
# 23           0.000000              -1_great_food_good_place
# 24           0.459904                 6_closed_open_pm_july
# 25           1.000000           21_ask_shes_waitress_waiter
# 26           0.000000              -1_great_food_good_place
# 27           1.000000               0_food_good_lunch_great
# 28           0.482369               0_food_good_lunch_great
# 29           0.000000              -1_great_food_good_place
# 30           0.362545               0_food_good_lunch_great
# 31           0.000000              -1_great_food_good_place
# 32           0.337255           21_ask_shes_waitress_waiter
# 33           0.000000              -1_great_food_good_place
# 34           0.665987          5_service_slow_rude_horrible
# 35           1.000000               0_food_good_lunch_great
# 36           0.000000              -1_great_food_good_place
# 37           0.370756               0_food_good_lunch_great
# 38           0.015339             12_parking_valet_lot_park
# 39           0.667439              10_place_miss_sucks_love
# 40           1.000000  9_reservations_reservation_wait_make
# 41           0.568288               0_food_good_lunch_great
# 42           0.000000              -1_great_food_good_place
# 43           1.000000               0_food_good_lunch_great
# 44           0.893363               0_food_good_lunch_great
# 45           0.000000              -1_great_food_good_place
# 46           0.264015               0_food_good_lunch_great
# 47           0.184541               8_cash_tip_atm_gratuity
# 48           0.756125          5_service_slow_rude_horrible
# 49           0.433447               0_food_good_lunch_great
#
# [50 rows x 31 columns]

# %% [markdown]
# ## Sentiment Counts

# %%
# prompt: count values of -1, 0 , 1 sentiment

sentiment_counts = merged_df['sentiment'].value_counts()
sentiment_counts
# Out:
# sentiment
# -1    1326
#  0    1326
#  1    1326
# Name: count, dtype: int64

# %%
# topics, probs = topic_model.fit_transform(merged_df['cleaned_tip_text'])

# Prepare the documents and sentiment classes
docs = merged_df['cleaned_tip_text'].tolist()

sentiment_classes = merged_df['sentiment'].astype(str).tolist()

# Calculate topic representations per sentiment class
topics_per_sentiment = topic_model.topics_per_class(docs, classes=sentiment_classes)

# Visualize the topics per sentiment class (showing top 10 topics per sentiment)
topic_model.visualize_topics_per_class(topics_per_sentiment, top_n_topics=30)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dc6ed9c5-22fd-4da4-bc29-9d10d33b8401" class="plotly-graph-div" style="height:900px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc6ed9c5-22fd-4da4-bc29-9d10d33b8401")) {                    Plotly.newPlot(                        "dc6ed9c5-22fd-4da4-bc29-9d10d33b8401",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: food, lunch, good, soup, great","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: food, service, good, chicken, lunch","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: food, great, lunch, good, service"],"marker":{"color":"#E69F00"},"name":"0_food_good_lunch_great","orientation":"h","visible":true,"x":[304,364,388],"y":["0","-1","1"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: pizza, italian, pasta, good, crust","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: pizza, italian, pasta, philly, best","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: pizza, italian, best, tampa, pasta"],"marker":{"color":"#56B4E9"},"name":"1_pizza_italian_pasta_best","orientation":"h","visible":"legendonly","x":[83,78,107],"y":["0","-1","1"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: refund, go, lets, back, dont","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: go, dont, money, waste, else","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: back, brooklynn, vedge, nonrowdy, gang"],"marker":{"color":"#009E73"},"name":"2_go_dont_money_back","orientation":"h","visible":"legendonly","x":[32,88,14],"y":["0","-1","1"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: beer, wine, bar, wines, craft","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: wine, beer, selection, bar, drinks","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: wine, beer, bar, beers, selection"],"marker":{"color":"#F0E442"},"name":"3_wine_beer_bar_selection","orientation":"h","visible":"legendonly","x":[61,19,43],"y":["0","-1","1"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: crab, legs, shrimp, fish, rangoon","\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: shrimp, calamari, crab, fish, lobster","\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: crab, shrimp, legs, lobster, ravioli"],"marker":{"color":"#D55E00"},"name":"4_crab_shrimp_legs_calamari","orientation":"h","visible":"legendonly","x":[35,18,38],"y":["0","-1","1"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: service, slow, rude, internet, reception","\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: service, rude, horrible, slow, manager","\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: service, customer, treating, rudely, rude"],"marker":{"color":"#0072B2"},"name":"5_service_slow_rude_horrible","orientation":"h","visible":"legendonly","x":[14,58,13],"y":["0","-1","1"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 6\u003c\u002fb\u003e\u003cbr\u003eWords: closed, open, sign, th, opening","\u003cb\u003eTopic 6\u003c\u002fb\u003e\u003cbr\u003eWords: closed, open, permanently, health, pm","\u003cb\u003eTopic 6\u003c\u002fb\u003e\u003cbr\u003eWords: closed, open, july, pm, reopening"],"marker":{"color":"#CC79A7"},"name":"6_closed_open_pm_july","orientation":"h","visible":"legendonly","x":[37,23,16],"y":["0","-1","1"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 7\u003c\u002fb\u003e\u003cbr\u003eWords:  ...

# %% [markdown]
# ## Cuisine Topic Modeling

# %%
# Function to extract a cuisine label from the categories column
def extract_cuisine(categories, cuisines_list=['Chinese', 'American', 'Italian']):
    if isinstance(categories, str):
        for cuisine in cuisines_list:
            if cuisine.lower() in categories.lower():
                return cuisine
    return 'Other'

# Create a new column 'cuisine' by applying the extraction function
merged_df['cuisine'] = merged_df['categories'].apply(extract_cuisine)

# Prepare the documents and cuisine classes
docs = merged_df['cleaned_tip_text'].tolist()
cuisine_classes = merged_df['cuisine'].tolist()

# Calculate topic representations per cuisine class using BERTopic
topics_per_cuisine = topic_model.topics_per_class(docs, classes=cuisine_classes)

# Visualize the top 30 topics per cuisine class
topic_model.visualize_topics_per_class(topics_per_cuisine, top_n_topics=30)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="47d29d16-72c2-4abd-bf5f-d9b8e97b8920" class="plotly-graph-div" style="height:900px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47d29d16-72c2-4abd-bf5f-d9b8e97b8920")) {                    Plotly.newPlot(                        "47d29d16-72c2-4abd-bf5f-d9b8e97b8920",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: food, lunch, great, good, service","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: food, great, service, good, lunch","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: food, soup, lunch, chicken, sushi"],"marker":{"color":"#E69F00"},"name":"0_food_good_lunch_great","orientation":"h","visible":true,"x":[263,333,460],"y":["Italian","American","Chinese"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: pizza, italian, pasta, good, best","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: tampa, pizza, italian, philly, bay","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: philly, tampa, pizza, best, bay"],"marker":{"color":"#56B4E9"},"name":"1_pizza_italian_pasta_best","orientation":"h","visible":"legendonly","x":[221,29,18],"y":["Italian","American","Chinese"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: dont, go, money, refund, waste","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: go, dont, back, bother, elsewhere","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: go, dont, money, waste, meh"],"marker":{"color":"#009E73"},"name":"2_go_dont_money_back","orientation":"h","visible":"legendonly","x":[53,40,41],"y":["Italian","American","Chinese"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: wine, beer, martinis, bar, glasses","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: beer, wine, bar, selection, beers","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: wine, bar, massages, graffiti, chug"],"marker":{"color":"#F0E442"},"name":"3_wine_beer_bar_selection","orientation":"h","visible":"legendonly","x":[31,80,12],"y":["Italian","American","Chinese"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: crab, calamari, lobster, ravioli, shrimp","\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: shrimp, crab, fish, lobster, legs","\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: crab, shrimp, legs, fish, rangoon"],"marker":{"color":"#D55E00"},"name":"4_crab_shrimp_legs_calamari","orientation":"h","visible":"legendonly","x":[27,26,38],"y":["Italian","American","Chinese"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: service, rude, manager, poor, reception","\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: service, slow, customer, manager, horrible","\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: service, horrible, rude, treating, rudely"],"marker":{"color":"#0072B2"},"name":"5_service_slow_rude_horrible","orientation":"h","visible":"legendonly","x":[22,37,26],"y":["Italian","American","Chinese"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 6\u003c\u002fb\u003e\u003cbr\u003eWords: closed, open, location, memorial, close","\u003cb\u003eTopic 6\u003c\u002fb\u003e\u003cbr\u003eWords: closed, open, pm, sign, closing","\u003cb\u003eTopic 6\u003c\u002fb\u003e\u003cbr\u003eWords: closed, open, july, pm, permanently"],"marker":{"color":"#CC79A7"},"name":"6_closed_open_pm_july","orientation":"h","visible":"legendonly","x":[25,26,25],"y":["Italian" ...

# %% [markdown]
# ## State Topic Modeling

# %%
# prompt: sample equal no. of 0 and 1 sentiments

# Calculate the number of samples for each sentiment class
n_samples_per_class = min(merged_df['sentiment'].value_counts())

# Sample equal number of 0 and 1 sentiments
sampled_df = pd.concat([
    merged_df[merged_df['sentiment'] == 0].sample(n=n_samples_per_class, random_state=42),
    merged_df[merged_df['sentiment'] == 1].sample(n=n_samples_per_class, random_state=42)
])

# Now 'sampled_df' contains an equal number of samples for each sentiment class.

# You can verify the counts:
print(sampled_df['sentiment'].value_counts())
# Out:
# sentiment
# 0    1326
# 1    1326
# Name: count, dtype: int64

# %%
# Prepare state classes from the 'state' column
sampled_docs = sampled_df['cleaned_tip_text'].tolist()
sentiment_classes = sampled_df['sentiment'].tolist()

# Calculate topic representations per state
topics_per_sentiment = topic_model.topics_per_class(sampled_docs, classes=sentiment_classes)

# Visualize the top 10 topics per state
topic_model.visualize_topics_per_class(topics_per_sentiment, top_n_topics=30)

# %%
# Prepare state classes from the 'state' column
state_classes = merged_df['state'].tolist()

# Calculate topic representations per state
topics_per_state = topic_model.topics_per_class(docs, classes=state_classes)

# Visualize the top 10 topics per state
topic_model.visualize_topics_per_class(topics_per_state, top_n_topics=30)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a08c3699-4998-4a00-9140-301c9f86fe1a" class="plotly-graph-div" style="height:900px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a08c3699-4998-4a00-9140-301c9f86fe1a")) {                    Plotly.newPlot(                        "a08c3699-4998-4a00-9140-301c9f86fe1a",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: food, lunch, good, great, soup","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: food, good, lunch, great, chicken"],"marker":{"color":"#E69F00"},"name":"0_food_good_lunch_great","orientation":"h","visible":true,"x":[502,554],"y":["PA","FL"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: pizza, italian, philly, pasta, best","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: pizza, italian, tampa, pasta, best"],"marker":{"color":"#56B4E9"},"name":"1_pizza_italian_pasta_best","orientation":"h","visible":"legendonly","x":[121,147],"y":["PA","FL"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: go, dont, money, meh, waste","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: go, dont, back, money, weeks"],"marker":{"color":"#009E73"},"name":"2_go_dont_money_back","orientation":"h","visible":"legendonly","x":[72,62],"y":["PA","FL"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: beer, wine, bar, selection, bartender","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: wine, beer, bar, wines, beers"],"marker":{"color":"#F0E442"},"name":"3_wine_beer_bar_selection","orientation":"h","visible":"legendonly","x":[71,52],"y":["PA","FL"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: crab, shrimp, lobster, fish, calamari","\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: crab, shrimp, legs, calamari, rangoon"],"marker":{"color":"#D55E00"},"name":"4_crab_shrimp_legs_calamari","orientation":"h","visible":"legendonly","x":[38,53],"y":["PA","FL"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: service, rude, slow, poor, horrible","\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: service, slow, horrible, manager, customer"],"marker":{"color":"#0072B2"},"name":"5_service_slow_rude_horrible","orientation":"h","visible":"legendonly","x":[34,51],"y":["PA","FL"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 6\u003c\u002fb\u003e\u003cbr\u003eWords: closed, open, sign, permanently, opening","\u003cb\u003eTopic 6\u003c\u002fb\u003e\u003cbr\u003eWords: closed, open, pm, july, close"],"marker":{"color":"#CC79A7"},"name":"6_closed_open_pm_july","orientation":"h","visible":"legendonly","x":[31,45],"y":["PA","FL"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 7\u003c\u002fb\u003e\u003cbr\u003eWords: chinese, szechuan, china, food, sichuan","\u003cb\u003eTopic 7\u003c\u002fb\u003e\u003cbr\u003eWords: chinese, sichuan, authentic, food, yummy"],"marker":{"color":"#E69F00"},"name":"7_chinese_sichuan_food_szechuan","orientation":"h","visible":"legendonly","x":[29,47],"y":["PA","FL"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 8\u003c\u002fb\u003e\u003cbr\u003eWords: cash, tip, atm, gratuity, cards","\u003cb\u003eTopic 8\u003c\u002fb\u003e\u003cbr\u003eWords: tip, cash, gratuity, charges, tea"],"marker":{"color":"#56B4E9"},"name":"8_cash_tip_atm_gratuity","orientation":"h","visible":"legendonly","x":[55,17],"y":["PA","FL"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 9\u003c ...
